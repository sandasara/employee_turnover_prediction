# 2             Assistant Manager - HR & Administration
# 3   Senior SAP S/4 HANA Consultant (Material Manag...
# 4   Assistant Manager - Engineering and Maintenanc...
# 5   Manager - Data Science & Analytics at MAS Inti...
# 6   at MAS | ex Marks & Spencer, Currys, Parexel, ...
# 7   Senior Executive - Technical operations at MAS...
# 8   Deputy Head of Business Finance Team at MAS In...
# 9   Manager - Organization Structure and Design at...
# 10  CGMA, ACMA(UK) I BBA(Hons) I Senior Management...
# 11                                        description
# 12  Central Autonomation Lead - Twinery - Innovati...
# 13   Deputy General Manager - Finance at MAS Holdings
# 14            Senior Business Analyst at MAS Holdings
# 15  General Manager - Human Resources at MAS Holdi...
# 16  Senior Business Application Support Consultant...
# 17       Senior Executive - Planning at MAS Intimates
# 18  Assistant Manager- Human Resources  at MAS Hol...
# 19  Senior Executive - HR Operations  at MAS Holdings
# 20  Head of HR at Twinery – MAS Innovation | ExCo ...
# 21  Senior Pattern Tech @ VS Bra |Garment Tech @ V...
# 22                   Senior Executive at MAS Holdings
# 23        Assistant Manager Planning  at MAS Holdings
#
#                                           location  followers  connections  \
# 0    Colombo District, Western Province, Sri Lanka        450          434
# 1               Kandy, Central Province, Sri Lanka         2K         500+
# 2             Colombo, Western Province, Sri Lanka        135          136
# 3                                        Sri Lanka        507         500+
# 4                                        Sri Lanka         4K         500+
# 5             Colombo, Western Province, Sri Lanka         5K         500+
# 6    Colombo District, Western Province, Sri Lanka        717         500+
# 7                                              NaN        NaN          NaN
# 8                                        Sri Lanka        418          419
# 9                                        Sri Lanka        637         500+
# 10                                             NaN        NaN          NaN
# 11                                        location  followers  connections
# 12                                       Sri Lanka        459          456
# 13                                       Sri Lanka         1K         500+
# 14                                             NaN        NaN          NaN
# 15                                       Sri Lanka        596         500+
# 16                                       Sri Lanka        727         500+
# 17            Colombo, Western Province, Sri Lanka        207          205
# 18                                       Sri Lanka         2K         500+
# 19                                       Sri Lanka        577         500+
# 20                                       Sri Lanka         3K         500+
# 21           Kaduwela, Western Province, Sri Lanka        151          151
# 22  Kalutara District, Western Province, Sri Lanka         18           17
# 23   Colombo District, Western Province, Sri Lanka        406          406
#
#                                                 about  \
# 0   Highly motivated and accomplished professional...
# 1   Is a Systematic Problem Solver, Ideologist, Pr...
# 2   Administrator/ Transportation & logistics/ Bud...
# 3   Information Technology Solutions Consultant sp...
# 4   I'm a BEng (Hons) Mechatronics Engineering gra...
# 5   I believe, I’m a person who can drive change a...
# 6   • Senior hands-on Analytics/Data Science/BI le...
# 7                                                 NaN
# 8   An accounting professional with more than 10+ ...
# 9                                                 NaN
# 10                                                NaN
# 11                                              about
# 12  Experienced Assistant Planning Manager skilled...
# 13                                                NaN
# 14  A graduate with over 8 years’ experience in mu...
# 15  Experienced Compensation Professional with mul...
# 16  A talented, ambitious and hardworking individu...
# 17                                                NaN
# 18  HR Professional with hands on experience in Mo...
# 19                           B.B.Mgt (HRM) (Kelaniya)
# 20  An HR Executive and Talent Development Leader ...
# 21                                                NaN
# 22  Multi-talented Senior Executive knowledgeable ...
# 23                                                NaN
#
#                                            experience  \
# 0   [{'position': 'Assistant Manager - Operations ...
# 1   [{'position': 'Process Improvement Consultant'...
# 2   [{'position': 'Assistant Manager - HR & Admini...
# 3   [{'position': 'Senior Solutions Architect', 'o...
# 4   [{'position': 'Assistant Manager - Engineering...
# 5   [{'position': 'Manager - Data Science & Analyt...
# 6   [{'position': 'Lead - Data Engineering & Scien...
# 7   [{'position': '', 'organisation': '', 'organis...
# 8   [{'position': 'Deputy Head of Business Finance...
# 9   [{'position': 'Manager - Organization Structur...
# 10  [{'position': '', 'organisation': '', 'organis...
# 11                                         experience
# 12  [{'position': 'Central Autonomation Lead', 'or...
# 13  [{'position': 'Deputy General Manager - Financ...
# 14  [{'position': '', 'organisation': '', 'organis...
# 15  [{'position': 'General Manager - Human Resourc...
# 16  [{'position': 'Senior Business Application Sup...
# 17  [{'position': 'Senior Executive - Planning', '...
# 18  [{'position': 'Assistant Manager Human Resourc...
# 19  [{'position': 'Senior Executive - Human Resour...
# 20  [{'position': 'Examiner of Cambridge Main suit...
# 21  [{'position': 'Senior Excecutive', 'organisati...
# 22  [{'position': 'Senior Executive Quality Assura...
# 23  [{'position': 'Assistant Manager Planning', 'o...
#
#                                             education  \
# 0   [{'organisation': 'University of Kelaniya Sri ...
# 1   [{'organisation': 'University of Kelaniya Sri ...
# 2   [{'organisation': 'University College Dublin',...
# 3   [{'organisation': '', 'organisation_profile': ...
# 4   [{'organisation': '', 'organisation_profile': ...
# 5   [{'organisation': 'University of Moratuwa', 'o...
# 6   [{'organisation': '', 'organisation_profile': ...
# 7   [{'organisation': 'University of Westminster',...
# 8   [{'organisation': 'Postgraduate Institute of M...
# 9   [{'organisation': 'Staffordshire University', ...
# 10  [{'organisation': 'University of Peradeniya', ...
# 11                                          education
# 12  [{'organisation': 'Cardiff Metropolitan Univer...
# 13  [{'organisation': 'Postgraduate Institute of M...
# 14  [{'organisation': 'University of Bedfordshire'...
# 15  [{'organisation': 'Edith Cowan University', 'o...
# 16  [{'organisation': 'University of Northampton',...
# 17  [{'organisation': 'University of Colombo', 'or...
# 18  [{'organisation': 'University of Colombo', 'or...
# 19  [{'organisation': 'University of Kelaniya Sri ...
# 20  [{'organisation': 'University of Colombo', 'or...
# 21  [{'organisation': '', 'organisation_profile': ...
# 22  [{'organisation': 'Wrexham Glyndŵr University'...
# 23  [{'organisation': 'University of Sri Jayewarde...
#
#                                        certifications  \
# 0   [{'certification_title': '', 'certification_is...
# 1   [{'certification_title': '', 'certification_is...
# 2                                                 NaN
# 3   [{'certification_title': 'SAP Certified Applic...
# 4   [{'certification_title': '', 'certification_is...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                     certifications
# 12  [{'certification_title': '', 'certification_is...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  [{'certification_title': '', 'certification_is...
# 21                                                NaN
# 22                                                NaN
# 23  [{'certification_title': 'Data Analytics for B...
#
#                                          publications  \
# 0   [{'publication_title': '', 'publication_link':...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                       publications
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  [{'publication_title': 'Managing Thyself to be...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#                                                awards
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [{'award_title': "President's Scout", 'award_g...
# 5                                                 NaN
# 6                                                 NaN
# 7   [{'award_title': 'First class BSC. (Hons.) in ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                             awards
# 12                                                NaN
# 13  [{'award_title': 'Top Affiliate in Sri Lanka -...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  [{'award_title': '1st Place- Most Innovative P...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN

# %%
print(df.columns)
# Out:
# Index(['profile', 'url', 'name', 'description', 'location', 'followers',
#        'connections', 'about', 'experience', 'education', 'certifications',
#        'publications', 'awards'],
#       dtype='object')

# %%
import pandas as pd
import ast


file_path = r'C:\Users\acer\Downloads\test.csv'


df = pd.read_csv(file_path)

# Use ast.literal_eval to safely parse the single-quoted JSON strings
df['experience'] = df['experience'].apply(ast.literal_eval)

# Create empty lists to store extracted data
profile_names = []
organization_profiles = []
positions = []
start_times = []
end_times = []
durations = []

# Iterate through the DataFrame and extract data
for idx, row in df.iterrows():
    name = row['name']  # Get the 'name' 
    experience_data = row['experience']
    
    for exp in experience_data:
        profile_names.append(name)
        organization_profiles.append(exp.get("organisation_profile", ""))
        positions.append(exp.get("position", ""))
        start_times.append(exp.get("start_time", ""))
        end_times.append(exp.get("end_time", ""))
        durations.append(exp.get("duration", ""))

# Create a DataFrame from the extracted data
extracted_data_df = pd.DataFrame({
    'Profile Name': profile_names,
    'Organization Profile': organization_profiles,
    'Position': positions,
    'Start Time': start_times,
    'End Time': end_times,
    'Duration': durations
})

# Define a function to convert duration to months
def duration_to_months(duration):
    if 'year' in duration:
        months = int(duration.split(' ')[0]) * 12
    elif 'month' in duration:
        months = int(duration.split(' ')[0])
    else:
        months = 0
    return months

# Apply the function to the 'Duration' column to calculate duration in months
extracted_data_df['Duration'] = extracted_data_df['Duration'].apply(duration_to_months)

print(extracted_data_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       2 import ast
#       5 file_path = r'C:\Users\acer\Downloads\test.csv'
# ----> 8 df = pd.read_csv(file_path)
#      10 # Use ast.literal_eval to safely parse the single-quoted JSON strings
#      11 df['experience'] = df['experience'].apply(ast.literal_eval)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\acer\\Downloads\\test.csv'

# %%
output_excel_path = 'output.xlsx'
extracted_data_df.to_excel(output_excel_path, index=False)

print(f'DataFrame has been saved to {output_excel_path}')
# Out:
# DataFrame has been saved to output.xlsx
